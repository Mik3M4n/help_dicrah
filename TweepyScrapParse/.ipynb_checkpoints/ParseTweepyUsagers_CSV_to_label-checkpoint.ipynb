# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Mon May 14 11:56:35 2018

@author: Eduard

Ce script sert à parser les messages texte des 20 Tweets aléatoires (+commentaires)
ayant été scrapés du compte de chaque usager dont nous avons détecté un message 
incorporant l'un de nos termes cible. Ils n'incorporent pas forcément l'un des 
mots-cibles, mais sont écrits par les mêmes usagers (introduction d'un dégré aléatoire).
Ils sont tous concatennés dans un fichier CSV pour lecture aisée sur Excel et 
labélisation manuelle.

"""
import json, glob, os
import pandas as pd


# On indique le chemin vers les fichiers JSON de Tweets scrappés
path = os.getcwd()+'/StreamListenerTweepy/Users/*.jsonl'


# On crée deux fonctions pour itérer le parse sur plusieurs fichiers JSON 
# placés sur le même dossier
def read_json_files(path_to_file):
    with open(path_to_file) as p:
        data = pd.read_json(p, lines=True)
    return data

def giant_list(json_files):
    data_list = []
    for f in json_files:
        data_list.append(read_json_files(f))
    return data_list


# Éxecution de fonctions et chargement de JSON dans un DF concatenné
event_files = glob.glob(path)
tweets = pd.concat(giant_list(event_files), ignore_index=True)
tweets = tweets[["retweeted_status"]]


# Extraction des index des lignes non vides et à parser
index_ret = tweets.retweeted_status[tweets.retweeted_status.notnull()].index


# Si le stream a un champ "extended_tweet" on récupère les index des ces tweets
# pour effectuer ensuite une boucle d'extraction du texte en entier.
j=[]
for i in index_ret:
    if "full_text" in tweets.retweeted_status[i]:
        j.append(i)
        
for i in j:
    tweets.retweeted_status[i] = tweets.retweeted_status[i]["full_text"]

    
# Enfin, on fusionne tous les tweets qui doivent être labelisées manuellement et on efface les dupliqués
tweets_dilcrah_users = tweets.stack().dropna().drop_duplicates().reset_index(drop=True)


# À cette fin, on exporte en csv pour pouvoir faire la lecture et labélisation sur Excel
tweets_dilcrah_users.to_csv('TweetsToLabelCSV/tweets_dilcrah_users.csv', sep=',', encoding='utf-8', header = False)


tweets_dilcrah_users
# Out:
# 0        Si vous voyez quelqu’un avec ce type de lunett...
# 1        She asked if she can say a bad word I’m lmfao ...
# 2               L’HOMME EST FAIBLE , LA FEMME EST MAUVAISE
# 3        Xvbarbar 2014-2015 aucun groupe trap n'a effle...
# 4        Toi qui lit ce tweet, je te souhaite de passer...
# 5        Qu'il profite bien de ses cheveux https://t.co...
# 6        "Meghan va devenir une femme, elle va s'embell...
# 7                                  https://t.co/r82wG9KT37
# 8        Jvous interdit de me donner de l’argent https:...
# 9        70 nouveaux épisodes de Rick &amp; Morty à ven...
# 10       Mon père il disait à l’école on l’appelait le ...
# 11       This so embarrassing😂 but look at us now🙊 #ble...
# 12       This is the accent I put on at work. I see you...
# 13       qui regarde fort boyard ? https://t.co/tdofXy1g6O
# 14       On fait parti de la génération MTV et MCM, en ...
# 15       "Les antillais ceci" , "les antillais cela" "s...
# 16                         Vrai negro n’a rien à prouver .
# 17       Juste pour bien recontextualiser les choses : ...
# 18       “Hey Chadwick! Wakanda Forev-“\n\nChadwick: ht...
# 19       on vit dans un monde où Aya Nakamura n’a pas c...
# 20       les femmes qui sortent avec des hommes noirs s...
# 21       Tu n'as donc jamais connu la route arc en ciel...
# 22       Quand on vous dit que c'est toujours ceux qui ...
# 23       Wiz Khalifa il est en train de guelar tout les...
# 24       😭😭😭😭😭 C'est iréél les américains c'est un gros...
# 25       ptdrrrr jurez c’est légal ça ? https://t.co/gN...
# 26       ptdr vous croyez les jamaïcains ils en ont que...
# 27       “Can you do the little arm thing?” https://t.c...
# 28       Plus tard je vais saucer ma hlel comme ça http...
# 29       Non mais c pas possible la Ils on le Haki de l...
#                                ...
# 10533    Je suis là seule qui aimerais me voir de l’ext...
# 10534    @LeSupplice @Abdoul_DJAFFAR Moi j’ai pas de bo...
# 10535    je préfère avoir 1% qu’habiter à Charleroi htt...
# 10536    Le français est une langue romane. Dans toutes...
# 10537    - tu fais quoi si tu gagnes au loto ? \n- http...
# 10538    Les hommes ils croient aux pubs “agrandir son ...
# 10539    On a un nouveau débat \nLes gens vous appelez ...
# 10540    Eh j'en peux plus 2011 j'étais folle http://t....
# 10541    Comment Bruxelles, capitale de l’Europe n’a pa...
# 10542    j’ai grv envie de me tatouer mdr mais l’islam ...
# 10543    Qd tu vois la machine à laver remplie de vêtem...
# 10544                   @closerfr  https://t.co/1DecUb95cv
# 10545    @Arabujin__ @JawadYougo Je me suis fait chopé ...
# 10546    Respecte l'être humain , car s'il n'est pas to...
# 10547    mais c tellement sous côtés les yeux marrons r...
# 10548    Arrêtez de dire "personne ne l'ouvre" quand vo...
# 10549    On a eu 4 jours de soleil on a cru c’était l’é...
# 10550    Cela dit si tu vois la tour Eiffel et le Troca...
# 10551    @TryBow_Mx @Medellin___ @chickensouag On se fa...
# 10552    Bonjour\nFOUTEZ DES POCHES INTÉRIEURES DANS LE...
# 10553           « ah ouais chaud » https://t.co/vM7QAaqRqT
# 10554    est-ce que les garçons parlent de nous à leurs...
# 10555                                    @ZahraZanaa 😂😂😂😂😂
# 10556    @sanchez08380 Je valoriserais jamais une corpu...
# 10557    Comment ne pas dire qu'un homme à tué sa femme...
# 10558    @BFMTV Pour votre prochain article sur un fémi...
# 10559    @Melo_Meyer @mordjenebm @Ilyansco @rebeccarihh...
# 10560    @Ilyansco @rebeccarihh Mdrr canalise ta jalous...
# 10561    @Tonton_Charlie1 Ton historien c’est le Raptor...
# 10562    Les raciste sur ce réseau c’est des malades......
# Length: 10563, dtype: object
