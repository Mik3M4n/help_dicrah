# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Mon May 14 11:56:35 2018

@author: msfogg
"""
import json, glob, os
import pandas as pd

# On indique le chemin vers les fichiers JSON de Tweets scrappés
path = os.getcwd()+'/StreamListenerTweepy/Streams/*.jsonl'

for filename in glob.glob(path):
    with open(filename) as json_data:
        df = pd.read_json(json_data, lines=True)
        
# On charge le JSON vers un DataFrame pandas
tweets = pd.DataFrame(df[["extended_tweet", "retweeted_status"]])

# Extraction des index des lignes non vides et à parser
index_ext = tweets.extended_tweet[tweets.extended_tweet.notnull()].index
index_ret = tweets.retweeted_status[tweets.retweeted_status.notnull()].index

# On remplace les tweets originaux et trunqués par le texte en entier
for i in index_ext:
    tweets["extended_tweet"][i] = tweets.extended_tweet[i]["full_text"]

# Pour les messages retweetés (reteewted_status) on a streamé un dict à plusiers niveaux
# Chaque json a une structure différente. Nous voulons récupérer deux champs:
# 1. les messages retweetés en entier et 2. les messages cités par le même usager

# 1. Si le stream a un champ "extended_tweet" on récupère les index des ces tweets
# pour effectuer ensuite une boucle d'extraction du texte en entier.
# Sinon (else), le message n'a pas été trunqué, on utilise le champ entier "text"
j=[]
for i in index_ret:
    if "extended_tweet" in tweets.retweeted_status[i]:
        j.append(i)
    else:
        tweets.retweeted_status[i] = tweets.retweeted_status[i]["text"]

for i in j:
    tweets.retweeted_status[i] = tweets.retweeted_status[i]["extended_tweet"]["full_text"]

# 2. Sur la même colonne d'avant on trouve le texte des messages cités par l'usager.  
# On l'a écrasée lors de l'opération précédente, on utilise 'df' à la place.
# Pour ne pas écraser la colonne sur 'tweets', on crée une nouvelle colonne 
# ou l'on placera le texte en entier
k=[]
for i in index_ret:
    if "quoted_status" in df.retweeted_status[i]:
        k.append(i)
    else:
        tweets["cite_status"] = None

try:
    for i in k:
        tweets.cite_status[i] = df.retweeted_status[i]["quoted_status"]["extended_tweet"]["full_text"]
except:
    pass

# Enfin, on fusionne tous les tweets qui doivent être labelisées manuellement
tweets_dilcrah = tweets.stack().dropna().reset_index(drop=True)

# À cette fin, on exporte en csv pour pouvoir faire la lecture et labélisation sur Excel
tweets_dilcrah.to_csv('TweetsToLabelCSV/tweets_dilcrah.csv', sep=',', encoding='utf-8', header = False)

tweets_dilcrah
# Out:
# /Users/msfogg/Desktop/Tweeter_scrap_20180512
# /Users/msfogg/Desktop/Tweeter_scrap_20180512/StreamListenerTweepy/Streams/*.jsonl
# 0      Grace Mbizi Lasexy est une journaliste ENGAGÉE...
# 1      Après l'Ecriture inclusive, la langue inclusiv...
# 2      les whites, ouvrez grand vos yeux et prenez en...
# 3      et y a moi, 19 ans, ki ressemble à un raton la...
# 4      @_Meuuuuh_ @Assasion1 @ciairlwt @Cybergally le...
# 5      Rappel: "beurette" c'est sexiste et raciste, c...
# 6      Quand je sens que la personne en face de moi e...
# 7      les whites, ouvrez grand vos yeux et prenez en...
# 8      Et voilà ça y est ! Pour l’inénarrable @Rokhay...
# 9      Donc la y’a tellement 3 white qui veulent m’ex...
# 10     Et voilà ça y est ! Pour l’inénarrable @Rokhay...
# 11     Et voilà ça y est ! Pour l’inénarrable @Rokhay...
# 12     et si en même temps les preuves de l'empoisonn...
# 13     les whites, ouvrez grand vos yeux et prenez en...
# 14     Et voilà ça y est ! Pour l’inénarrable @Rokhay...
# 15     Donc la y’a tellement 3 white qui veulent m’ex...
# 16     Mais oui puisque les mots ont attendu vos avis...
# 17     Que Dieu nous eloigne des gens qui quand vs de...
# 18     @TartineDisperse Je n’ai proféré aucune injure...
# 19     si y’a un endroit que je déteste sur Terre c’e...
# 20     Que toutes les personnes qui parlent de racism...
# 21     @celine_pina @RokhayaDiallo Est-ce de l’humour...
# 22     Et voilà ça y est ! Pour l’inénarrable @Rokhay...
# 23     La République encore une fois attaquée à #Cham...
# 24     Et voilà ça y est ! Pour l’inénarrable @Rokhay...
# 25     Toi déjà t’es un menteur j’suis sur t’as zero ...
# 26     allons allons la racaille s'amuse, il est ou l...
# 27     Et voilà ça y est ! Pour l’inénarrable @Rokhay...
# 28     Va falloir songer à la soigner et dire que ça ...
# 29     Et voilà ça y est ! Pour l’inénarrable @Rokhay...
#                              ...
# 196    @LDespls @Apteam_of_life @ChLECHEVALIER @Franc...
# 197    Si vous voyez quelqu’un avec ce type de lunett...
# 198    Décès de Naomi Musenga : Tout drame qui touche...
# 199    les whites, ouvrez grand vos yeux et prenez en...
# 200    Les vieux raciste dans les transports qui insu...
# 201    Que toutes les personnes qui parlent de racism...
# 202    La République encore une fois attaquée à #Cham...
# 203    @AdriendlRocque Jte le repete nique ta mere ya...
# 204    les whites, ouvrez grand vos yeux et prenez en...
# 205    J'ai zéro à l'école, c'est parce que je suis n...
# 206    et y a moi, 19 ans, ki ressemble à un raton la...
# 207    Les vieux raciste dans les transports qui insu...
# 208    Que toutes les personnes qui parlent de racism...
# 209    Sans compter les affreuses mutilations de nomb...
# 210    mais vas y déjà juste tu leur dis "vous les bl...
# 211    J'ai zéro à l'école, c'est parce que je suis n...
# 212    La République encore une fois attaquée à #Cham...
# 213    "Selon moi ", ça me tue quand on vous explique...
# 214    Que toutes les personnes qui parlent de racism...
# 215    Les vieux raciste dans les transports qui insu...
# 216    Et voilà ça y est ! Pour l’inénarrable @Rokhay...
# 217    on est les meilleurs simplement 🤷🏾‍♂️ https://...
# 218    Et voilà ça y est ! Pour l’inénarrable @Rokhay...
# 219    tu " n'exiges""  rien du tout !!! Pauvre bicot...
# 220    Mais oui puisque les mots ont attendu vos avis...
# 221    Si vous voyez quelqu’un avec ce type de lunett...
# 222    Hier soir, le commissariat de #Champigny a été...
# 223    Que toutes les personnes qui parlent de racism...
# 224    Ma question de la journée sera simple : où son...
# 225    @montagnette1 Sans compter les affreuses mutil...
# Length: 226, dtype: object
